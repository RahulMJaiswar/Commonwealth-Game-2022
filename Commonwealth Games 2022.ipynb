# %% [markdown]
# Some special points in the Commonwealth Games 2022 are different from every last few years
# 	1.
# 	• Steeplechase is a sport where Kenya win every year from 1998-2018 from bronze to Gold Kenya won all Medals
# 	• But this year we had a miracle, Avinash Sable won the Silver Medals in Steeplechase
# 	• He made a new National Record
# 	2. Sharath kamal
# 	• Some people want much more than 1 medal. even after winning a gold, medal they say "Yeh Dil Mange More"
# 	• India table tennis star Sharath Kamal is one of them he won not only 1 but 4 medals for India CWG
# 	• Let me tell you Sharath Kamal is 40 years old and has won medals before too
# 	• We think an athlete loses his skills as he ages, reactions are slower and young players get more medals than older players
# 	• But Sharath Kamal has proved everyone wrong
#
# 	3. Vinesh Phogat :
# 	• By winnings a gold medal Vinesh Phogat earned a hat trick of gold
# 	• She is the first Indian woman to win 3 consecutive golds at CWG
# 	• And her achievement is quite special because she lost her quarterfinal bout at Tokyo Olympic
# 	• Ans she admitted she was in poor mental and physical health she thought of quitting wrestling  but she didn’t quit
# 	• Coming back from that low to win gold is a huge stamp
# PV Sindhu
# 	•    PV Sindhu had an injury to her left ankle even then she got gold medals for the country.
#
# 	4. Women's T20 Cricket
# 	• Women's T20 cricket made a debut in the CWG this time and we all Indian love cricket but only men's cricket
# 	• Women's cricket does not get the same respect but this is now slowly changing
# 	• After the 2017 Women's World Cup our perspective towards women's cricket changed this was cemented in CWG this year that our girls are no less
# 	• England and Australia dominate every year team in women's cricket but we defeat England in the Semi-Finals match and we enter the gold medals match.
# 	• And we came too close to defeating Australia as well we came so close to winning the gold medals
#
# 	5. Can a Tailor brings home medals in weightlifting?
# 	• This is the story of Achinta Sheuli
# 	• He comes from Deulpur in West Bengal
# 	• His father drove a van and he passed away in 2013 leaving a little to the family
# 	• His mother started embroidery to keep the family afloat
# 	• Even they did not have money for their father's last rites
# 	• Achinta's elder brother Alok himself was a weightlifter but looking at their financial condition he understood the family could not support 2 athlete so athletes other gave up his weightlifting dream and ask his younger brother to dream big
#
# 	6. We won double medals in the triple jump event gold and silver
# 	• Eldhose Paul won gold medals and create history whereas Abdulla won the silver medals
# 	• Only our Indian jumpers crossed the 17m mark in the contest
# 	• Indians  don't generally dominate any athletics event
# 	• We don’t have Geneticetic advantages like Africancan's and we don't have developed training facilities
# 	• But yet our athletes win medals even in such adverse situations our respect for them does double
#
# 	7. Para Athletes
# 	• Our Para Athlete's also made their mark at the CWG
# 	• We won our first medals in para powerlifting and that to was  a good
# 	• Sudhir won the gold in heavyweight powerlifting (212 Kg)
# 	• We saw our para athlete might at the  paralympic  last year and they made a mark at the CWG as well
#
# 	8. Can India have a 100% win record in a sport
# 	• Sound Impossible!
# 	• But this happened in CWG this time
# 	• We won most medals in wrestling this time
# 	• The most amazing thing is that 12 athlete's participated in wrestling and all of them won medals .12/12 meaning a 100% success  rate
# 	• Along with some legends like Bajrang Punia of the wrestling world we get to cheer for some never names as well (Naveen Malik)
#
# 	9. Lawn Balls
# 	• We never heard a game about Lawn Balls but our women's team defeated South Africa in the  finals
# 	• There is small balls called either jack or kitty
# 	• You have to ensure your bowls are close to the jack than the opponents
# 	• It looks simple but it isn't so it's quite exciting when you think about it that the sport which majority of Indians  had not even heard of was one this athlete's made their career in and they won a gold medal as well
#
# 	10. In 2010 we won 101 medals and we were in 2nd rank
# In shooting we get the most number of medals as compared to the other country but in the 2022 commonwealth Games, there is no shooting game. Australia is the highest medals taker in 2022 but suppose to think if there is no swimming game in CWG 2022 then supposed what was the Australia conditions or Australia medals tally look like!

# %%
#Importing Libraries

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
import warnings

# %%
# %matplotlib inline

# %% [markdown]
# Indian medal winner dataset

# %%
ind = pd.read_csv("D:\Commonwealth Games 2022\Indian_medal_winners_CWgames2022.csv")

# %% [markdown]
# Country Medals Dataset

# %%
 country = pd.read_csv("D:\Commonwealth Games 2022\Countrywise_medals_CWgames2022.csv")

# %%
country.head()
# Out:
#    Unnamed: 0  Rank      Country  Gold  Silver  Bronze  Total
# 0           0     1    Australia    67      57      54    178
# 1           1     2      England    56      65      53    175
# 2           2     3       Canada    26      32      34     92
# 3           3     4        India    22      16      23     61
# 4           4     5  New Zealand    20      12      17     49

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  43 non-null     int64
#  1   Rank        43 non-null     int64
#  2   Country     43 non-null     object
#  3   Gold        43 non-null     int64
#  4   Silver      43 non-null     int64
#  5   Bronze      43 non-null     int64
#  6   Total       43 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.5+ KB

# %%
country.drop(['Unnamed: 0'],axis =1,inplace = True)

# %%
plt.figure(figsize=(15,15))
plt.barh('Country','Total',data = country, label ='TOTAL',color = '#96c8a2')
plt.barh('Country','Gold',data= country,label ='GOLD',color='#ffd700')
plt.barh('Country','Silver',data= country,label ='SILVER',color='#C0C0C0')
plt.barh('Country','Bronze',data= country,label ='BRONZE',color='#b08d57')

for index,value in enumerate (country['Total']):
    plt.text(value,index,
             str(value))
plt.grid(axis='x')
plt.title('Country Vs Number of Medals')
plt.xticks(rotation =90,fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# Indian Players in Commonwealth Game 2022

# %%
ind = pd.read_csv("D:\Commonwealth Games 2022\Indian_medal_winners_CWgames2022.csv")

# %%
ind.head()
# Out:
#    Unnamed: 0  No        Athlete/Team   Medal         Event          Sport  \
# 0           0   1       Sanket Sargar  Silver    Men's 55kg  Weightlifting
# 1           1   2    Gururaja Poojary  Bronze    Men's 61kg  Weightlifting
# 2           2   3      Mirabai Chanbu    Gold  Women's 49kg  Weightlifting
# 3           3   4     Bindyarani Devi  Silver  Women's 55kg  Weightlifting
# 4           4   5  Jeremy Lalrinnunga    Gold    Men's 67kg  Weightlifting
#
#          State  Gender
# 0  Maharashtra    Male
# 1     Karnatka    Male
# 2      Manipur  Female
# 3      Manipur  Female
# 4      Mizoram  Female

# %%
ind.drop (['Unnamed: 0'],axis=1,inplace = True)

# %%
ind.head(10)
# Out:
#    No           Athlete/Team   Medal          Event          Sport  \
# 0   1          Sanket Sargar  Silver     Men's 55kg  Weightlifting
# 1   2       Gururaja Poojary  Bronze     Men's 61kg  Weightlifting
# 2   3         Mirabai Chanbu    Gold   Women's 49kg  Weightlifting
# 3   4        Bindyarani Devi  Silver   Women's 55kg  Weightlifting
# 4   5     Jeremy Lalrinnunga    Gold     Men's 67kg  Weightlifting
# 5   6         Achinta Sheuli    Gold      Mens 73kg  Weightlifting
# 6   7  Sushila Devi Likmabam  Silver   Women's 48kg           Judo
# 7   8      Vijay Kumar Yadav  Bronze     Men's 60kg           Judo
# 8   9         Harjinder Kaur  Bronze   Women's 71kg  Weightlifting
# 9  10    Indian women's team    Gold  Women's fours     Lawn bowls
#
#            State  Gender
# 0    Maharashtra    Male
# 1       Karnatka    Male
# 2        Manipur  Female
# 3        Manipur  Female
# 4        Mizoram  Female
# 5    West Bengal    Male
# 6        Manipur    Male
# ...

# %%
ax = sns.countplot(ind['Medal'],edgecolor = 'black')
plt.xlabel('Medal Type',fontsize =20)
plt.ylabel ('Number Of Medals',fontsize =20)
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.25),fontsize=12)
    
plt.title('INDIA',fontsize = 20)
plt.show()

# %%
option =['Gold']
plt.figure(figsize =(15,8))
colors=['#FF9933','#D1D1D1','#138808']
ax = sns.countplot(ind[ind['Medal'].isin(option)]['Sport'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=25)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('Sport',fontsize =20)
plt.ylabel('Number of Gold Medals',fontsize =20)
plt.title('Gold Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
option =['Silver']
plt.figure(figsize =(15,8))
colors=['#FF9933','#D1D1D1','#138808']
ax = sns.countplot(ind[ind['Medal'].isin(option)]['Sport'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor ='black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=25)
plt.xticks(rotation =68,fontsize =15)
plt.xlabel('Sport',fontsize =20)
plt.ylabel('Number of Silver Medals',fontsize =20)
plt.title('Silver Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
option =['Bronze']
plt.figure(figsize =(15,8))
colors=['#FF9933','#D1D1D1','#138808']
ax = sns.countplot(ind[ind['Medal'].isin(option)]['Sport'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'Black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=25)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('Sport',fontsize =20)
plt.ylabel('Number of Bronze Medals',fontsize =20)
plt.title('Bronze Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
option =['Gold']
plt.figure(figsize =(20,10))
colors=['#FF9933','#D1D1D1','#138808']
ax =sns.countplot(ind[ind['Medal'].isin(option)]['State'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'Black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=30)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('State',fontsize =20)
plt.ylabel('Number of Gold Medals',fontsize =20)
plt.title('State-Wise Gold Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
option =['Silver']
plt.figure(figsize =(20,10))
colors=['#FF9933','#D1D1D1','#138808']
ax =sns.countplot(ind[ind['Medal'].isin(option)]['State'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'Black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=30)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('State',fontsize = 20)
plt.ylabel('Number of Silver Medals',fontsize =20)
plt.title('State-Wise Silver Medals',fontsize=20)
plt.grid(axis='y')
plt.show()

# %%
option =['Bronze']
plt.figure(figsize =(20,10))
colors=['#FF9933','#D1D1D1','#138808']
ax=sns.countplot(ind[ind['Medal'].isin(option)]['State'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.01),fontsize=30)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('State',fontsize =20)
plt.ylabel('Number of Brone Medals',fontsize =20)
plt.title('State-Wise Bronze Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
option =['Gold']
plt.figure(figsize =(15,8))
colors=['#FF9933','#D1D1D1','#138808']
ax = sns.countplot(ind[ind['Medal'].isin(option)]['Gender'],palette = sns.set_palette(sns.color_palette(colors,8)),edgecolor = 'Black')
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.05),fontsize=20)
plt.xticks(rotation =45,fontsize =20)
plt.xlabel('Gender',fontsize =20)
plt.ylabel('Number of Medals',fontsize =20)
plt.title('Total Number of Medals',fontsize =20)
plt.grid(axis='y')
plt.show()

# %%
ax = sns.countplot(ind['Gender'],edgecolor = 'Black')
plt.xlabel('Gender Type',fontsize =20)
plt.ylabel ('Number Of Medals',fontsize =20)
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+.25,p.get_height()+.75),fontsize=12)
    
plt.title('INDIA',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20,8))
ax = sns.countplot(ind['State'],edgecolor='black',linewidth = 1)
sns.set_palette(sns.color_palette(colors,200))
for p in ax.patches: ax.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.10,p.get_height()+.25),fontsize=20)
plt.xticks(rotation =45,fontsize=15)
plt.xlabel('State',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('State Vs Number Of Medal',fontsize = 20)
plt.show()

# %%
plt.hist(x=ind['Medal'],color = 'red')
plt.xlabel('Medal',fontsize =15)
plt.ylabel('Numbers of Medal',fontsize =15)
plt.title('Distribution of Medal')
plt.xticks(fontsize =15,color ='black')
plt.yticks(fontsize = 15,color ='black')
plt.grid('True')
plt.xlim()
plt.show()

# %%
plt.figure(figsize=(35,25))
plt.hist(x=ind['State'],color = 'green',edgecolor = 'black',linewidth ='1')
plt.xlabel('State',fontsize =25)
plt.ylabel('Count',fontsize =25)
plt.title('Distribution of Medal according to State',fontsize = 30)
plt.xticks(fontsize =15,color ='black')
plt.yticks(fontsize = 20,color ='black')

plt.show()

# %%
plt.boxplot(country['Gold'],vert= True,patch_artist=True)
colors = ['Orchid']
plt.title('Distribution of Gold')
plt.xlabel('Gold')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.boxplot(country['Total'],vert= True,patch_artist=True)
colors = ['Orchid']
plt.title('Distribution of Total Medal')
plt.xlabel('Medal')
plt.show()

# %%
df = pd.DataFrame(ind)

# %%
ind.head()
# Out:
#    No        Athlete/Team   Medal         Event          Sport        State  \
# 0   1       Sanket Sargar  Silver    Men's 55kg  Weightlifting  Maharashtra
# 1   2    Gururaja Poojary  Bronze    Men's 61kg  Weightlifting     Karnatka
# 2   3      Mirabai Chanbu    Gold  Women's 49kg  Weightlifting      Manipur
# 3   4     Bindyarani Devi  Silver  Women's 55kg  Weightlifting      Manipur
# 4   5  Jeremy Lalrinnunga    Gold    Men's 67kg  Weightlifting      Mizoram
#
#    Gender
# 0    Male
# 1    Male
# 2  Female
# 3  Female
# 4  Female

# %%
df1 = pd.DataFrame(country)

# %%
country.head()
# Out:
#    Rank      Country  Gold  Silver  Bronze  Total
# 0     1    Australia    67      57      54    178
# 1     2      England    56      65      53    175
# 2     3       Canada    26      32      34     92
# 3     4        India    22      16      23     61
# 4     5  New Zealand    20      12      17     49

# %%
df['Medal'].value_counts().plot(kind ='bar',color = 'lightpink',edgecolor = 'black')
plt.xlabel('Medal',fontsize = 15)
plt.ylabel('Counts',fontsize =15)
plt.title('Medal Distribution',fontsize =20)
plt.xticks(fontsize =12)
plt.yticks(fontsize =12)
plt.show()

# %%
ind.head()
# Out:
#    No        Athlete/Team   Medal         Event          Sport        State  \
# 0   1       Sanket Sargar  Silver    Men's 55kg  Weightlifting  Maharashtra
# 1   2    Gururaja Poojary  Bronze    Men's 61kg  Weightlifting     Karnatka
# 2   3      Mirabai Chanbu    Gold  Women's 49kg  Weightlifting      Manipur
# 3   4     Bindyarani Devi  Silver  Women's 55kg  Weightlifting      Manipur
# 4   5  Jeremy Lalrinnunga    Gold    Men's 67kg  Weightlifting      Mizoram
#
#    Gender
# 0    Male
# 1    Male
# 2  Female
# 3  Female
# 4  Female

# %%
plt.figure(figsize=(10,8))
wedgeprops = {"linewidth": 1, 'width':1, "edgecolor":"k"}
frequency_by_medal = ind['Medal'].value_counts()
keys = frequency_by_medal.keys().to_list()
counts = frequency_by_medal.to_list()
plt.pie(x = counts, labels = keys, autopct ='%1.1f%%',textprops= {'fontsize': 20},wedgeprops = wedgeprops)
plt.title('Medal Wise Distribution',fontsize = 20)
plt.show()

# %%
from matplotlib import cm

# %%
plt.figure(figsize=(10,8))
explode = (0.1,0.01,0.01)
wedgeprops = {"linewidth": 2, 'width':1, "edgecolor":"k"}
frequency_by_medal = ind['Medal'].value_counts()
keys = frequency_by_medal.keys().to_list()
counts = frequency_by_medal.to_list()
plt.pie(x = counts, labels = keys, autopct ='%1.1f%%',explode = explode,textprops= {'fontsize': 20},wedgeprops =wedgeprops )
plt.title('Medal Type Distribution',fontsize =20)
plt.show()
cs = cm.Set1([2,4,6,8])

# %%
wedgeprops = {"linewidth": 2, 'width':1, "edgecolor":"k"}
plt.figure(figsize=(20,20))
frequency_by_medal = ind['State'].value_counts()
keys = frequency_by_medal.keys().to_list()
counts = frequency_by_medal.to_list()
plt.pie(x = counts, labels = keys, autopct ='%1.1f%%',textprops= {'fontsize': 20},wedgeprops = wedgeprops)
plt.title('State Wise Performance',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20,30))
wedgeprops = {"linewidth": 1, 'width':1, "edgecolor":"k"}
frequency_by_medal = ind['Sport'].value_counts()
keys = frequency_by_medal.keys().to_list()
counts = frequency_by_medal.to_list()
plt.pie(x = counts, labels = keys, autopct ='%1.1f%%',textprops= {'fontsize': 20},wedgeprops =wedgeprops)
plt.title('Medal Wise Distribution',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(10,8))
explode = (0.1,0,0)
wedgeprops = {"linewidth": 1, 'width':1, "edgecolor":"k"}
frequency_by_medal = ind['Medal'].value_counts()
keys = frequency_by_medal.keys().to_list()
counts = frequency_by_medal.to_list()
plt.title('Medal Wise Distribution',fontsize = 20)
circle = plt.Circle (xy = (0,0),radius = 0.4 , color ='white')
plt.pie(x = counts, labels = keys, autopct ='%1.1f%%',textprops= {'fontsize': 20},wedgeprops = wedgeprops,explode =explode)
plt.gcf()
plt.gca().add_artist(circle)
plt.show()

# %%
plt.scatter(x = 'Gold', y = 'Silver', data = country)
plt.xlabel('Gold')
plt.ylabel('Silver')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
plt.scatter(x = 'Silver', y = 'Bronze', data = country)
plt.xlabel('Silver')
plt.ylabel('Bronze')
plt.title('Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
sns.stripplot(x ='Gold',y = 'Silver',data = country)
plt.title('Strip Plot for Gold and Silver')
plt.show()

# %%
sns.distplot (country['Gold'],color ='olive')
plt.title('Distribution Of Country Gold')
plt.show()

# %%
sns.distplot (country['Gold'],color ='olive',kde = False)
plt.title('Distribution Of Country Gold')
plt.show()

# %%
sns.distplot (country['Silver'],color ='olive')
plt.title('Distribution Of Country Silver')
plt.show()

# %%
sns.distplot (country['Bronze'],color ='olive')
plt.title('Distribution Of Country Bronze')
plt.show()

# %%
sns.jointplot (x = 'Gold', y = 'Silver', data = country,color = 'sandybrown')
plt.show()

# %%
sns.violinplot ( x= 'Gold', y ='Silver', data = country)
plt.title('Violin plot for Gold and Silver')
plt.show()

# %%
sns.pairplot(data = ind)
plt.show()

# %%
sns.pairplot(data = country)
plt.show()

# %%
sns.heatmap(data = ind.corr(),annot = True,linewidth = 0.5 ,cmap ='Blues' ,cbar = True,vmin =-1 , vmax = 1)
plt.show()

# %%
sns.heatmap(data =country.corr(),annot = True,linewidth = 0.5 ,cmap ='Blues' ,cbar = True,vmin =-1 , vmax = 1)
plt.show()
